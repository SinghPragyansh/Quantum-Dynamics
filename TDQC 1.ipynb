# %%
import scipy as sc
import numpy as np
import matplotlib.pyplot as plt
a=sc.sqrt(16)
print(a)
# Out:
# 4.0
# C:\Users\Pragyansh\AppData\Local\Temp/ipykernel_47292/2074871995.py:4: DeprecationWarning: scipy.sqrt is deprecated and will be removed in SciPy 2.0.0, use numpy.lib.scimath.sqrt instead
#   a=sc.sqrt(16)

# %%
b=np.sqrt(29)
print(b)
# Out:
# 5.385164807134504

# %%
c = np.arange(10,30,10)
print(c)
# Out:
# [10 20]

# %%
x = np.random.randint(2,10,5)
print(x)
# Out:
# [9 5 7 6 6]

# %%
y = np.random.randint(10,20,5)
print(y)
# Out:
# [10 10 18 19 10]

# %%
plt.plot(x,y,'*-',color="orange")

# %%
a = 50
da=10
while a<=90:
    b=a*2
    print(a,b)
    plt.plot(a,b,'-*')
    a=a+da
# Out:
# 50 100
# 60 120
# 70 140
# 80 160
# 90 180

# %%
k = np.arange(0,10.0,0.1)
l = np.sin(k)
plt.plot(k,l,'*-' )
plt.xlabel("Numbers") 
plt.ylabel("Sine function")
plt.savefig("Sine PLOT.png")
